# %%
from math import remainder

x = 3
y = 5
z = 2
x, y, z
# Out:
# (3, 5, 2)

# %%
multiplyxy = x * y * 10
multiplyxy
# Out:
# 150

# %%
powerz = z ** 5
powerz
# Out:
# 32

# %%
remainderxy = x % y
remainderxy
# Out:
# 3
