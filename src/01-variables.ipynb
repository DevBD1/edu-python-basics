# %%
anInteger = 5
anotherInteger = 10

# %%
print("anInteger =", anInteger, "anotherInteger =", anotherInteger, sep = " ")
# Out:
# anInteger = 5 anotherInteger = 10

# %%
type(anInteger)
# Out:
# int

# %%
divide = anotherInteger/anInteger
print(type(divide), divide)
# Out:
# <class 'float'> 2.0

# %%
multiply = anInteger * anotherInteger
print(type(multiply), multiply)
# Out:
# <class 'int'> 50
