# %%
myStringInput = input("Input a string: ")
myStringInput
# Out:
# 'mehmet burak dorman'

# %%
myIntInput = input("Input an integer: (123456789)")
int(myIntInput)
myIntInput
# Out:
# '123456789'

# %%
myInputLength = len(myString)
myInputLength
# Out:
# 9

# %%
myStringInput[-1]
# Out:
# '!'

# %%
myIntInput[2:]
# Out:
# 'llo!'

# %%
myIntInput[:3]
# Out:
# 'Hel'

# %%
myIntInput[:-2]
# Out:
# 'Hell'

# %%
myIntInput[-2:]
# Out:
# 'o!'

# %%
myIntInput[2:4]
# Out:
# 'll'

# %%
myIntInput[2:10:2]
# Out:
# '3579'

# %%
myIntInput[::3]
# Out:
# '147'

# %%
myIntInput[::-1]
# Out:
# '987654321'

# %%
myStringInput.capitalize()
# Out:
# 'Hello!'

# %%
myIntInput.isdigit()
# Out:
# True

# %%
myStringInput.split("e")
# Out:
# ['m', 'hm', 't burak dorman']

# %%
myStringInput + " - " + "AAA"
# Out:
# 'mehmet burak dorman - AAA'
