# %%
myList = [1, 2, 3]
myList
# Out:
# [1, 2, 3]

# %%
anotherList = [4, 5, 6]
myList.append(anotherList)
myList
# Out:
# [1, 2, 3, [4, 5, 6]]

# %%
myList[3][0]
# Out:
# 4

# %%
myDict = {"apple": 51, "banana": 69, "pear": 90}
myDict
# Out:
# {'apple': 51, 'banana': 69, 'pear': 90}

# %%
myDict["banana"]
# Out:
# 69

# %%
anotherDict = {"apple": 1, "banana": 2, "cherry": 3}
anotherDict
# Out:
# {'apple': 1, 'banana': 2, 'cherry': 3}

# %%
anotherDict.pop("cherry")
anotherDict
# Out:
# {'apple': 1, 'banana': 2}

# %%
clist = ["alist", "blist"]
crazyDict = {"list": clist, "MBD": [1, 6, 9]}
anotherDict.update(crazyDict)
anotherDict
# Out:
# {'apple': 1, 'banana': 2, 'list': ['alist', 'blist'], 'MBD': [1, 6, 9]}
