# %%
class ConvertDogAgeHumanAge():
    def __init__(self, dog_age = 0):
        dog_age = input("Köpeğin yaşını giriniz: ")
        self.human_age = int(dog_age)*7
        print("İnsan yaşı karşılığı: ", self.human_age, "")

# %%
ConvertDogAgeHumanAge()
# Out:
# İnsan yaşı karşılığı:  42
