# %%
from nbclient.jsonutil import encode_images

liste1 = [1, 2, 3]

# %%
liste2 = [6, 5, 4]

# %%
zipped = zip(liste1, liste2)
zipped

# %%
list(zipped)
# Out:
# [(1, 6), (2, 5), (3, 4)]

# %%
list(enumerate(liste1))
# Out:
# [(0, 1), (1, 2), (2, 3)]

# %%
import random

# %%
roll = random.randint(1, 6)
print(roll)
# Out:
# 2

# %%
random.shuffle(liste1)
liste1
# Out:
# [2, 3, 1]
