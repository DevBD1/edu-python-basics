# %%
import random

# %%
listem = [random.randint(1, 10) for _ in range(6)]
listem
# Out:
# [8, 4, 2, 1, 3, 1]

# %%
uniqueList = random.sample(range(1, 101), 6)
uniqueList
# Out:
# [66, 24, 16, 54, 47, 21]

# %%
def toplama(*args):
    return sum(args)

# %%
emList = []

# %%
for eleman in uniqueList:
    if eleman not in emList:
        emList.append(eleman)
        print(emList)
# Out:
# [66]
# [66, 24]
# [66, 24, 16]
# [66, 24, 16, 54]
# [66, 24, 16, 54, 47]
# [66, 24, 16, 54, 47, 21]

# %%
kareler = list(map(lambda x: x**2, uniqueList))
print(kareler)
# Out:
# [4356, 576, 256, 2916, 2209, 441]

# %%
sonuclar = list(filter(lambda x: x%2==0, kareler))
print(sonuclar)
# Out:
# [4356, 576, 256, 2916]
